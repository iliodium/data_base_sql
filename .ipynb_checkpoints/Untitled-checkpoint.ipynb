# %%
import os
import uuid
import psycopg2
import numpy as np
import scipy.interpolate
import scipy.io as sio
import matplotlib.cm as cm
import matplotlib.tri as mtri
import matplotlib.pyplot as plt

from psycopg2 import Error
from scipy.fft import fft, rfftfreq

# %%
x1=[[0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29], [0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29]]
x2=[[0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39], [0.31, 0.33, 0.35, 0.37, 0.39]]
x3=[[0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69], [0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69]]
x4=[[0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79], [0.71, 0.73, 0.75, 0.77, 0.79]]
x_old = [np.array(x1),np.array(x2),np.array(x3),np.array(x4)]

# %%
z1=[[0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125], [0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375], [0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625], [0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875], [0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125], [0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375], [0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625], [0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875]]
z2=[[0.28125, 0.28125, 0.28125, 0.28125, 0.28125], [0.24375, 0.24375, 0.24375, 0.24375, 0.24375], [0.20625, 0.20625, 0.20625, 0.20625, 0.20625], [0.16875, 0.16875, 0.16875, 0.16875, 0.16875], [0.13125, 0.13125, 0.13125, 0.13125, 0.13125], [0.09375, 0.09375, 0.09375, 0.09375, 0.09375], [0.05625, 0.05625, 0.05625, 0.05625, 0.05625], [0.01875, 0.01875, 0.01875, 0.01875, 0.01875]]
z3=[[0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125, 0.28125], [0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375, 0.24375], [0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625, 0.20625], [0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875, 0.16875], [0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125, 0.13125], [0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375, 0.09375], [0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625, 0.05625], [0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875, 0.01875]]
z4=[[0.28125, 0.28125, 0.28125, 0.28125, 0.28125], [0.24375, 0.24375, 0.24375, 0.24375, 0.24375], [0.20625, 0.20625, 0.20625, 0.20625, 0.20625], [0.16875, 0.16875, 0.16875, 0.16875, 0.16875], [0.13125, 0.13125, 0.13125, 0.13125, 0.13125], [0.09375, 0.09375, 0.09375, 0.09375, 0.09375], [0.05625, 0.05625, 0.05625, 0.05625, 0.05625], [0.01875, 0.01875, 0.01875, 0.01875, 0.01875]]
z_old = [np.array(z1),np.array(z2),np.array(z3),np.array(z4)]

# %%
a4=[[-0.7528446960449244, -0.8059956054687539, -0.8555208435058623, -0.8516265563964782, -0.8273246459960952], [-0.804835662841804, -0.8027238464355418, -0.8331852111816416, -0.8210174865722646, -0.7893598937988285], [-0.8322001647949233, -0.8209064636230495, -0.8254289855957052, -0.8074064331054738, -0.7818209838867218], [-0.8256332702636695, -0.8152848205566376, -0.8241249389648495, -0.8106489868164016, -0.7846591186523438], [-0.821168395996097, -0.8074474487304729, -0.8202146911621148, -0.8106145935058581, -0.7831036376953124], [-0.8035019531249976, -0.7952957458496078, -0.8171238403320308, -0.8094010620117174, -0.7838856811523386], [-0.736362365722657, -0.7606354675292976, -0.8035823669433576, -0.8276163635253903, -0.8090685424804732], [-0.5782383728027322, -0.6010419006347678, -0.6378656921386668, -0.6344732360839855, -0.5631067199707037]]
pressure_coefficients=[np.array(a1),np.array(a2),np.array(a3),np.array(a4)]

# %%
minn = np.min(np.array(a1)),np.min(np.array(a2)),np.min(np.array(a3)),np.min(np.array(a4))
print(min(minn))
minv = np.round(min(minn),1)
maxn = np.max(np.array(a1)),np.max(np.array(a2)),np.max(np.array(a3)),np.max(np.array(a4))
print(max(maxn))
maxv = np.round(max(maxn),1)
print(minv,maxv)
# Out:
# -0.8555208435058623
# 0.7776953125000018
# -0.9 0.8

# %%
levels = np.arange(minv,maxv+0.1,0.1)
b,d,h=0.3,0.1,0.3

# %%
for i in range(len(x1)):
    x1[i] = [0] + x1[i]+[b]
    x2[i] = [b] + x2[i]+[b+d]
    x3[i] = [b+d] + x3[i]+[2 * b + d]
    x4[i] = [2 * b + d] + x4[i]+[2 * (b + d)]

x1.append(x1[0])
x2.append(x2[0])    
x3.append(x3[0])    
x4.append(x4[0])    

x1.insert(0,x1[0])
x2.insert(0,x2[0])    
x3.insert(0,x3[0])    
x4.insert(0,x4[0]) 
    
x_new=[np.array(x1),np.array(x2),np.array(x3),np.array(x4)]

# %%
for i in range(len(z1)):
    z1[i] = [z1[i][0]] + z1[i]+[z1[i][0]]
    z2[i] = [z2[i][0]] + z2[i]+[z2[i][0]]
    z3[i] = [z3[i][0]] + z3[i]+[z3[i][0]]
    z4[i] = [z4[i][0]] + z4[i]+[z4[i][0]]
    
z1.append([0 for i in range(len(z1[0]))])
z2.append([0 for i in range(len(z2[0]))])
z3.append([0 for i in range(len(z3[0]))])
z4.append([0 for i in range(len(z4[0]))])

z1.insert(0,[h for i in range(len(z1[0]))])
z2.insert(0,[h for i in range(len(z2[0]))])
z3.insert(0,[h for i in range(len(z3[0]))])
z4.insert(0,[h for i in range(len(z4[0]))])

z_new=[np.array(z1),np.array(z2),np.array(z3),np.array(z4)]

# %%
import scipy.interpolate

# %%
x=np.array([1,2,3])
x-=10
x
# Out:
# array([-9, -8, -7])

# %%
def rbf_func(coords,val):
    return scipy.interpolate.RBFInterpolator(coords,val)

# %%
z = z_old
x = x_old

# %%
fig, graph = plt.subplots(1, 4)
cmap = cm.get_cmap(name="jet")
for i in range(4):
    x2 = x_new[i].reshape(1, -1)[0]
    x1 = x[i].reshape(1, -1)[0]
    if i == 1:
        x1 = x1 - b
    elif i == 2:
        x1 = x1 - (b + d)
    elif i == 3:
        x1 = x1 - (2 * b + d)
    
    if i == 1:
        x2 = x2 - b
    elif i == 2:
        x2 = x2 - (b + d)
    elif i == 3:
        x2 = x2 - (2 * b + d)
        
    z2 = z_new[i].reshape(1, -1)[0]    
    z1 = z[i].reshape(1, -1)[0]
    a = pressure_coefficients[i].reshape(1, -1)[0]
    print(a)
    coords = [[i1,j1] for i1,j1 in zip(x1,z1)]
    interpolater = rbf_func(coords,a)
    print(len(x1),len(z1),len(a))
    a2 = [float(interpolater([[x7,z7]])) for x7,z7 in zip(x2,z2)]
    print(a2)
    print(len(x2),len(z2),len(a2))
    triang = mtri.Triangulation(x2, z2)
    refiner = mtri.UniformTriRefiner(triang)
    grid, value = refiner.refine_field(a2, subdiv=4)
    
    data_colorbar =graph[i].tricontourf(grid, value, cmap=cmap, levels=levels)
    aq = graph[i].tricontour(grid, value, linewidths=1, linestyles='solid', colors='black',levels=levels)
    graph[i].clabel(aq, fontsize=10)
    graph[i].set_ylim([0,h])
    if i in [0,2]:
        graph[i].set_xlim([0,b])
        graph[i].set_xticks(ticks=np.arange(0,b+0.1,0.1))
    else:
        graph[i].set_xlim([0,d])
        graph[i].set_xticks(ticks=np.arange(0,d+0.1,0.1))

fig.colorbar(data_colorbar, ax=graph, location='bottom', cmap=cmap,ticks=levels)
plt.show()
plt.close()
# Out:
# [0.43905103 0.58569492 0.61913275 0.62782715 0.62450903 0.61682687
#  0.61343674 0.61208578 0.60441669 0.59547318 0.57505804 0.58150888
#  0.56442252 0.52661984 0.34990979 0.41075665 0.65400806 0.72952448
#  0.75918909 0.77365695 0.77547354 0.77769531 0.77340543 0.76451236
#  0.75108804 0.73476126 0.70829904 0.66738434 0.57661688 0.32914026
#  0.33691336 0.58713586 0.67832394 0.71995963 0.73958176 0.74862866
#  0.74900174 0.74577353 0.73781171 0.72320032 0.70419186 0.67207562
#  0.61894955 0.51877603 0.27358502 0.25569672 0.51165115 0.59330295
#  0.63815756 0.66004767 0.67120151 0.6745058  0.6717695  0.66202527
#  0.64771362 0.6307757  0.59356863 0.54008548 0.43846283 0.18999438
#  0.18173352 0.40581296 0.49315381 0.54280588 0.57008649 0.58830661
#  0.58942062 0.59028058 0.58349225 0.56803168 0.54359113 0.50471793
#  0.45012274 0.34551404 0.10780939 0.07329303 0.30833096 0.41256757
#  0.47647525 0.51394778 0.53739532 0.55009634 0.54990134 0.54093121
# ...
